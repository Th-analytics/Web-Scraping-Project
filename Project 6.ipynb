# %% [markdown]
# ## Project Overview
# The objective of this project is to afford you the opportunity to demonstrate the
# skills acquired over the course of the semester.  Specifically, you will be constructing
# an analytics-ready dataset using data from several disparate, but related data sources.
#
# Your dataset is to be a pandas dataframe suitable for answering the proof-of-concept
# questions located at the end of this document.
#
# ### The Scenario
# You are the proprietor of a small tour company.  You are interested in launching a new app
# that will allow users to undertake self-guided tours of noteworthy authors. To launch your app
# you need to assemble the authors' location information along with some other facts that you
# believe will be of interest to your customers.
#
# ## Data Sources
# You will be collecting and assembling data from several different sources and formats.
# 1. Source 1 - web scraping
# 1. Source 2 - delimitted file
# 1. Source 3 - direct download XML file
# 1. Source 4 - Zip Code API
#
# ## Project Teams
# Working on a team is not a requirement and you may complete the project on your own.
# Thus, project team(s) may be composed of 1 or **at most** 2 students. If you are working
# with another student please, ensure both of your names are clearly visible in your final solution JNB.

# %% [markdown]
# ### Source 1: Initial Author Data
# The initial list of author names is to be web-scraped from a popular "famous quotes" website.
# There are 50 unique authors available from this site.  Begin your exploration at the base
# URL and determine your own strategy to find and capture the required author data.
#
# Depending on your approach, you may encounter the same author multiple times.
# In the end, your list of authors should be duplicate free.
#
# ```
# Base Scrape URL: https://quotes.toscrape.com
# ```
# #### Tasks
# 1. Beginning at the Base Scrape URL given above, you are to use a web scraping technique to collect
# the following author information:
# * Full Name
# * Date of birth
# * Birth location
# 2. Create a pandas dataframe from (or using) the relevant data

# %%
import pandas as pd
import requests
import html5lib
from bs4 import BeautifulSoup as BS

# %%
URL = 'https://quotes.toscrape.com'
nameOfAuthors = {}
set_ =set()
flag = True
nextLink = URL
detailsOfAuthors =[]

def call(url):
    response = requests.get(url)
    #print('Response:',response)
    dta = response.content
    dta = BS(response.content,'html5lib')
    return dta

def nameScrapper(webUrl):
    data = call(webUrl)
    rawData = data.findAll('div',attrs={'class':'quote'})
    for i in rawData:
        if i.a['href'] not in set_:
            set_.add(f"{URL}{i.a['href']}")
            nameOfAuthors[i.small.text] = f"{URL}{i.a['href']}"

data = call(URL)

while(flag):
    data = call(nextLink)
    #print(nextLink)
    nameScrapper(nextLink)
    try:
        next_ = data.find('li',attrs={'class':'next'}).a.text.split()[0]
        nLink = data.find('li',attrs={'class':'next'}).a['href']
    except:
        flag = False
    finally:
        #print(nLink)
        if next_ == 'Next':
            nextLink = f"{URL}{nLink}"

            
for name_,li_nk in nameOfAuthors.items():
    rawData = call(li_nk)
    dob = rawData.find('span',attrs={'class':'author-born-date'}).text
    birthPlace = rawData.find('span',attrs={'class':'author-born-location'}).text.replace('in','')
    detailsOfAuthors.append([name_, dob ,birthPlace]) 
    
df1 = pd.DataFrame(detailsOfAuthors,columns=['Name of Author','Date of Birth','Place of Birth'])
df1
# Out:
#             Name of Author       Date of Birth  \
# 0          Albert Einstein      March 14, 1879
# 1             J.K. Rowling       July 31, 1965
# 2              Jane Austen   December 16, 1775
# 3           Marilyn Monroe       June 01, 1926
# 4               André Gide   November 22, 1869
# 5         Thomas A. Edison   February 11, 1847
# 6        Eleanor Roosevelt    October 11, 1884
# 7             Steve Martin     August 14, 1945
# 8               Bob Marley   February 06, 1945
# 9                Dr. Seuss      March 02, 1904
# 10           Douglas Adams      March 11, 1952
# 11             Elie Wiesel  September 30, 1928
# 12     Friedrich Nietzsche    October 15, 1844
# 13              Mark Twain   November 30, 1835
# 14          Allen Saunders      April 24, 1899
# 15            Pablo Neruda       July 12, 1904
# 16     Ralph Waldo Emerson        May 25, 1803
# 17           Mother Teresa     August 26, 1910
# 18        Garrison Keillor     August 07, 1942
# 19              Jim Henson  September 24, 1936
# 20       Charles M. Schulz   November 26, 1922
# 21       William Nicholson    January 12, 1948
# 22       Jorge Luis Borges     August 24, 1899
# 23            George Eliot   November 22, 1819
# 24      George R.R. Martin  September 20, 1948
# 25              C.S. Lewis   November 29, 1898
# 26  Martin Luther King Jr.    January 15, 1929
# 27           James Baldwin     August 02, 1924
# 28         Haruki Murakami    January 12, 1949
# 29    Alexandre Dumas fils       July 27, 1824
# 30         Stephenie Meyer   December 24, 1973
# 31        Ernest Hemingway       July 21, 1899
# 32            Helen Keller       June 27, 1880
# 33     George Bernard Shaw       July 26, 1856
# 34        Charles Bukowski     August 16, 1920
# 35         Suzanne Collins     August 11, 1962
# 36          J.R.R. Tolkien    January 03, 1892
# 37         Alfred Tennyson     August 06, 1809
# 38         Terry Pratchett      April 28, 1948
# 39           J.D. Salinger    January 01, 1919
# 40           George Carlin        May 12, 1937
# 41             John Lennon    October 09, 1940
# 42             W.C. Fields    January 29, 1880
# 43                Ayn Rand   February 02, 1905
# 44            Jimi Hendrix   November 27, 1942
# 45             J.M. Barrie        May 09, 1860
# 46           E.E. Cummings    October 14, 1894
# 47         Khaled Hosseini      March 04, 1965
# 48              Harper Lee      April 28, 1926
# 49       Madeleine L'Engle   November 29, 1918
#
#                                        Place of Birth
# 0                                        Ulm, Germany
# 1    Yate, South Gloucestershire, England, The Uni...
# 2      Steventon Rectory, Hampshire, The United Kgdom
# 3                                   The United States
# 4                                       Paris, France
# 5                      Milan, Ohio, The United States
# 6                                   The United States
# 7                      Waco, Texas, The United States
# 8                           Ne Mile, Sat Ann, Jamaica
# 9                    Sprgfield, MA, The United States
# 10               Cambridge, England, The United Kgdom
# 11                                    Sighet, Romania
# 12   Röcken bei Lützen, Prussian Provce of Saxony,...
# 13               Florida, Missouri, The United States
# 14                                  The United States
# 15                                      Parral, Chile
# 16           Boston, Massachusetts, The United States
# 17   Skopje, Macedonia, the Former Yugoslav Republ...
# 18                  Anoka, Mnesota, The United States
# 19         Greenville, Mississippi, The United States
# 20                   Mneapolis, MN, The United States
# 21                    Lewes, Sussex, The United Kgdom
# 22                              Buenos Aires, Argenta
# 23   South Farm, Arbury Hall, Nuneaton, Warwickshi...
# 24             Bayonne, New Jersey, The United States
# 25                                   Belfast, Ireland
# 26                Atlanta, Georgia, The United States
# 27                Harlem, New York, The United States
# 28                                       Kyoto, Japan
# 29                                      Paris, France
# 30                     Connecticut, The United States
# 31                Oak Park, Illois, The United States
# 32              Tuscumbia, Alabama, The United States
# 33                                      Dubl, Ireland
# 34                                 Andernach, Germany
# 35           Hartford, Connecticut, The United States
# 36     Bloemfonte, Mangaung, Free State, South Africa
# 37             Somersby, Lcolnshire, The United Kgdom
# 38   Beaconsfield, Buckghamshire, England, The Uni...
# 39             Manhattan, New York, The United States
# 40              New York, New York, The United States
# 41               Liverpool, England, The United Kgdom
# 42             Darby, Pennsylvania, The United States
# 43                 St. Petersburg, Russian Federation
# 44               Seattle, Washgton, The United States
# 45      Kirriemuir, Angus, Scotland, The United Kgdom
# 46        Cambridge, Massachusetts, The United States
# 47                                 Kabul, Afghanistan
# 48            Monroeville, Alabama, The United States
# 49         New York City, New York, The United States

# %% [markdown]
# ### Source 2: Author Key Data
# For each of the 50 authors previously identified, you are to merge a key and gender value available
# from a CSV file with the author data from *Source 1*.
#
# ```
# CSV File: *author_key_file.csv*
# ```
# #### Tasks
# 1. The author names are unique in both
# data sources and thus may be used to associate the *key* and *gender* attribute values with the author.
# 3. Once you have completed the merge, convert the *key* column to be the dataframe's row index.

# %%
author_key = pd.read_csv('author_key_file.csv',names=["Name of Author","key","gender"])
authorDf =pd.merge(author_key,df1,on='Name of Author',how='right') 
authorDf.set_index('key',inplace=True)
authorDf
# Out:
#                   Name of Author gender       Date of Birth  \
# key
# QWxiZXJ0         Albert Einstein      M      March 14, 1879
# Si1LLVJv            J.K. Rowling      F       July 31, 1965
# SmFuZS1B             Jane Austen      F   December 16, 1775
# TWFyaWx5          Marilyn Monroe      F       June 01, 1926
# QW5kcmUt              André Gide      M   November 22, 1869
# VGhvbWFz        Thomas A. Edison      M   February 11, 1847
# RWxlYW5v       Eleanor Roosevelt      F    October 11, 1884
# U3RldmUt            Steve Martin      M     August 14, 1945
# Qm9iLU1h              Bob Marley      M   February 06, 1945
# RHItU2V1               Dr. Seuss      M      March 02, 1904
# RG91Z2xh           Douglas Adams      M      March 11, 1952
# RWxpZS1X             Elie Wiesel      M  September 30, 1928
# RnJpZWRy     Friedrich Nietzsche      M    October 15, 1844
# TWFyay1U              Mark Twain      M   November 30, 1835
# QWxsZW4t          Allen Saunders      M      April 24, 1899
# UGFibG8t            Pablo Neruda      M       July 12, 1904
# UmFscGgt     Ralph Waldo Emerson      M        May 25, 1803
# TW90aGVy           Mother Teresa      F     August 26, 1910
# R2Fycmlz        Garrison Keillor      M     August 07, 1942
# SmltLUhl              Jim Henson      M  September 24, 1936
# Q3hhcmxl       Charles M. Schulz      M   November 26, 1922
# V2lsbGlh       William Nicholson      M    January 12, 1948
# Sm9yZ2Ut       Jorge Luis Borges      M     August 24, 1899
# R4Vvcmdl            George Eliot      F   November 22, 1819
# R5Vvcmdl      George R.R. Martin      M  September 20, 1948
# Qy1TLUxl              C.S. Lewis      M   November 29, 1898
# TWFydGlu  Martin Luther King Jr.      M    January 15, 1929
# SmFtZXMt           James Baldwin      M     August 02, 1924
# SGFydWtp         Haruki Murakami      M    January 12, 1949
# QWxleGFu    Alexandre Dumas fils      M       July 27, 1824
# U3RlcGhl         Stephenie Meyer      F   December 24, 1973
# RXJuZXN0        Ernest Hemingway      M       July 21, 1899
# SGVsZW4t            Helen Keller      F       June 27, 1880
# R2Vvcmdl     George Bernard Shaw      M       July 26, 1856
# Q2hhcmxl        Charles Bukowski      M     August 16, 1920
# U3V6YW5u         Suzanne Collins      F     August 11, 1962
# Si1SLVIt          J.R.R. Tolkien      M    January 03, 1892
# QWxmcmVk         Alfred Tennyson      M     August 06, 1809
# VGVycnkt         Terry Pratchett      M      April 28, 1948
# Si1ELVNh           J.D. Salinger      M    January 01, 1919
# R3Vvcmdl           George Carlin      M        May 12, 1937
# Sm9obi1M             John Lennon      M    October 09, 1940
# Vy1DLUZp             W.C. Fields      M    January 29, 1880
# QXluLVJh                Ayn Rand      F   February 02, 1905
# SmltaS1I            Jimi Hendrix      M   November 27, 1942
# Si1NLUJh             J.M. Barrie      M        May 09, 1860
# RS1FLUN1           E.E. Cummings      M    October 14, 1894
# S2hhbGVk         Khaled Hosseini      M      March 04, 1965
# SGFycGVy              Harper Lee      F      April 28, 1926
# TWFkZWxl       Madeleine L'Engle      F   November 29, 1918
#
#                                              Place of Birth
# key
# QWxiZXJ0                                       Ulm, Germany
# Si1LLVJv   Yate, South Gloucestershire, England, The Uni...
# SmFuZS1B     Steventon Rectory, Hampshire, The United Kgdom
# TWFyaWx5                                  The United States
# QW5kcmUt                                      Paris, France
# VGhvbWFz                     Milan, Ohio, The United States
# RWxlYW5v                                  The United States
# U3RldmUt                     Waco, Texas, The United States
# Qm9iLU1h                          Ne Mile, Sat Ann, Jamaica
# RHItU2V1                   Sprgfield, MA, The United States
# RG91Z2xh               Cambridge, England, The United Kgdom
# RWxpZS1X                                    Sighet, Romania
# RnJpZWRy   Röcken bei Lützen, Prussian Provce of Saxony,...
# TWFyay1U               Florida, Missouri, The United States
# QWxsZW4t                                  The United States
# UGFibG8t                                      Parral, Chile
# UmFscGgt           Boston, Massachusetts, The United States
# TW90aGVy   Skopje, Macedonia, the Former Yugoslav Republ...
# R2Fycmlz                  Anoka, Mnesota, The United States
# SmltLUhl         Greenville, Mississippi, The United States
# Q3hhcmxl                   Mneapolis, MN, The United States
# V2lsbGlh                    Lewes, Sussex, The United Kgdom
# Sm9yZ2Ut                              Buenos Aires, Argenta
# R4Vvcmdl   South Farm, Arbury Hall, Nuneaton, Warwickshi...
# R5Vvcmdl             Bayonne, New Jersey, The United States
# Qy1TLUxl                                   Belfast, Ireland
# TWFydGlu                Atlanta, Georgia, The United States
# SmFtZXMt                Harlem, New York, The United States
# SGFydWtp                                       Kyoto, Japan
# QWxleGFu                                      Paris, France
# U3RlcGhl                     Connecticut, The United States
# RXJuZXN0                Oak Park, Illois, The United States
# SGVsZW4t              Tuscumbia, Alabama, The United States
# R2Vvcmdl                                      Dubl, Ireland
# Q2hhcmxl                                 Andernach, Germany
# U3V6YW5u           Hartford, Connecticut, The United States
# Si1SLVIt     Bloemfonte, Mangaung, Free State, South Africa
# QWxmcmVk             Somersby, Lcolnshire, The United Kgdom
# VGVycnkt   Beaconsfield, Buckghamshire, England, The Uni...
# Si1ELVNh             Manhattan, New York, The United States
# R3Vvcmdl              New York, New York, The United States
# Sm9obi1M               Liverpool, England, The United Kgdom
# Vy1DLUZp             Darby, Pennsylvania, The United States
# QXluLVJh                 St. Petersburg, Russian Federation
# SmltaS1I               Seattle, Washgton, The United States
# Si1NLUJh      Kirriemuir, Angus, Scotland, The United Kgdom
# RS1FLUN1        Cambridge, Massachusetts, The United States
# S2hhbGVk                                 Kabul, Afghanistan
# SGFycGVy            Monroeville, Alabama, The United States
# TWFkZWxl         New York City, New York, The United States

# %%
len(authorDf)
# Out:
# 50

# %% [markdown]
# ### Source 3: Author Location Data
# This direct download XML data source contains the location information that will be used
# to direct app users to the historical sites associated with each author.  The *id*
# tag can be used to match the previously assembled author data (ie, the *key* attribute) with
# the author location data.
#
# You are to retain all of the location attributes (excluding *id* - which will be a
# duplicate of the existing *key* attribute) from this data source to extend the
# previously collected author data.
#
# ```
# Direct Download URL: https://www.drivehq.com/file/DFPublishFile.aspx/FileID7657515244/Keycqacws4cypvo/author_location_data.xml
# Data Format: XML
# Encoding: UTF-8
# ```
# #### Tasks
# 1. Ingest the XML data into a pandas dataframe
# 2. Use the pandas dataframe merge method to join the new dataframe
# with the Source 1+2 dataframe.
# 3. *Source 3* contains location data for many public figures in addition
# to the 50 authors in which we are currently interested. You must restrict your
# final Source 3 dataframe to our 50 authors.

# %%
import xml.etree.ElementTree as et
from urllib.request import urlopen

# %%
xmldoc =urlopen('https://www.drivehq.com/file/DFPublishFile.aspx/FileID7657515244/Keycqacws4cypvo/author_location_data.xml')
tree= et.parse(xmldoc)
root = tree.getroot()

# %%
dataList =[]
for i in root.findall('./location'):
    id_ = i.find('id').text
    price = i.find('price').text
    bedrooms = i.find('bedrooms').text
    bathrooms = i.find('bathrooms').text
    sqft_living = i.find('sqft_living').text
    sqft_lot = i.find('sqft_lot').text
    floors = i.find('floors').text
    waterfront = i.find('waterfront').text
    grade= i.find('grade').text
    yr_built= i.find('yr_built').text
    lat= i.find('lat').text
    long= i.find('long').text
    dataList.append([id_,price,bedrooms,bathrooms,sqft_living,sqft_lot,floors,waterfront,grade,yr_built,lat,long])

# %%
detailDf = pd.DataFrame(dataList,columns = ["key","price","bedrooms","bathrooms","sqft_living","sqft_lot","floors","waterfront","grade","yr_built","lat","long"])
detailDf
# Out:
#           key    price bedrooms bathrooms sqft_living sqft_lot floors  \
# 0    99744767   271310        2         1         870     5340    1.5
# 1    74681995   503500        3       2.5        1810     1750      2
# 2    53154276  2574000        4      3.75        4475    20424      2
# 3    Q3hhcmxl   134000        2       1.5         980     5000      2
# 4    SmltaS1I   284200        3      1.75        1540     6632      1
# ..        ...      ...      ...       ...         ...      ...    ...
# 491  19602869   270000        3      1.75        1610     6205      1
# 492  18124298   291375        4       2.5        2220     6233      2
# 493  17897404   435000        3         1        1050     5500      1
# 494  U3RlcGhl   200000        4         2        1920     4822      1
# 495  95149109   279000        4         2        1980    10051      1
#
#     waterfront grade yr_built      lat       long
# 0            0     6     1906  34.5892   -94.2250
# 1            0     7     1997  39.3953   -76.7000
# 2            1    12     1999  38.0293  -108.0640
# 3            0     7     1922  38.0329   -78.4703
# 4            0     7     1959  39.9894   -81.1697
# ..         ...   ...      ...      ...        ...
# 491          0     7     1979  30.2608   -97.7325
# 492          0     7     2001  40.5940   -80.2120
# 493          0     6     1920  42.6666   -73.3691
# 494          0     6     1914  21.3055  -157.8447
# 495          0     7     1969  31.0708   -96.9608
#
# [496 rows x 12 columns]

# %%
source3 = pd.merge(authorDf,detailDf,on='key',how='inner')
source3
# Out:
#          key          Name of Author gender       Date of Birth  \
# 0   QWxiZXJ0         Albert Einstein      M      March 14, 1879
# 1   Si1LLVJv            J.K. Rowling      F       July 31, 1965
# 2   SmFuZS1B             Jane Austen      F   December 16, 1775
# 3   TWFyaWx5          Marilyn Monroe      F       June 01, 1926
# 4   QW5kcmUt              André Gide      M   November 22, 1869
# 5   VGhvbWFz        Thomas A. Edison      M   February 11, 1847
# 6   RWxlYW5v       Eleanor Roosevelt      F    October 11, 1884
# 7   U3RldmUt            Steve Martin      M     August 14, 1945
# 8   Qm9iLU1h              Bob Marley      M   February 06, 1945
# 9   RHItU2V1               Dr. Seuss      M      March 02, 1904
# 10  RG91Z2xh           Douglas Adams      M      March 11, 1952
# 11  RWxpZS1X             Elie Wiesel      M  September 30, 1928
# 12  RnJpZWRy     Friedrich Nietzsche      M    October 15, 1844
# 13  TWFyay1U              Mark Twain      M   November 30, 1835
# 14  QWxsZW4t          Allen Saunders      M      April 24, 1899
# 15  UGFibG8t            Pablo Neruda      M       July 12, 1904
# 16  UmFscGgt     Ralph Waldo Emerson      M        May 25, 1803
# 17  TW90aGVy           Mother Teresa      F     August 26, 1910
# 18  R2Fycmlz        Garrison Keillor      M     August 07, 1942
# 19  SmltLUhl              Jim Henson      M  September 24, 1936
# 20  Q3hhcmxl       Charles M. Schulz      M   November 26, 1922
# 21  V2lsbGlh       William Nicholson      M    January 12, 1948
# 22  Sm9yZ2Ut       Jorge Luis Borges      M     August 24, 1899
# 23  R4Vvcmdl            George Eliot      F   November 22, 1819
# 24  R5Vvcmdl      George R.R. Martin      M  September 20, 1948
# 25  Qy1TLUxl              C.S. Lewis      M   November 29, 1898
# 26  TWFydGlu  Martin Luther King Jr.      M    January 15, 1929
# 27  SmFtZXMt           James Baldwin      M     August 02, 1924
# 28  SGFydWtp         Haruki Murakami      M    January 12, 1949
# 29  QWxleGFu    Alexandre Dumas fils      M       July 27, 1824
# 30  U3RlcGhl         Stephenie Meyer      F   December 24, 1973
# 31  RXJuZXN0        Ernest Hemingway      M       July 21, 1899
# 32  SGVsZW4t            Helen Keller      F       June 27, 1880
# 33  R2Vvcmdl     George Bernard Shaw      M       July 26, 1856
# 34  Q2hhcmxl        Charles Bukowski      M     August 16, 1920
# 35  U3V6YW5u         Suzanne Collins      F     August 11, 1962
# 36  Si1SLVIt          J.R.R. Tolkien      M    January 03, 1892
# 37  QWxmcmVk         Alfred Tennyson      M     August 06, 1809
# 38  VGVycnkt         Terry Pratchett      M      April 28, 1948
# 39  Si1ELVNh           J.D. Salinger      M    January 01, 1919
# 40  R3Vvcmdl           George Carlin      M        May 12, 1937
# 41  Sm9obi1M             John Lennon      M    October 09, 1940
# 42  Vy1DLUZp             W.C. Fields      M    January 29, 1880
# 43  QXluLVJh                Ayn Rand      F   February 02, 1905
# 44  SmltaS1I            Jimi Hendrix      M   November 27, 1942
# 45  Si1NLUJh             J.M. Barrie      M        May 09, 1860
# 46  RS1FLUN1           E.E. Cummings      M    October 14, 1894
# 47  S2hhbGVk         Khaled Hosseini      M      March 04, 1965
# 48  SGFycGVy              Harper Lee      F      April 28, 1926
# 49  TWFkZWxl       Madeleine L'Engle      F   November 29, 1918
#
#                                        Place of Birth    price bedrooms  \
# 0                                        Ulm, Germany   699999        3
# 1    Yate, South Gloucestershire, England, The Uni...   415000        3
# 2      Steventon Rectory, Hampshire, The United Kgdom   300000        3
# 3                                   The United States  2480000        4
# 4                                       Paris, France   425000        3
# 5                      Milan, Ohio, The United States   179900        2
# 6                                   The United States   420000        3
# 7                      Waco, Texas, The United States   761000        3
# 8                           Ne Mile, Sat Ann, Jamaica   307150        3
# 9                    Sprgfield, MA, The United States   550000        3
# 10               Cambridge, England, The United Kgdom   528000        3
# 11                                    Sighet, Romania   418395        4
# 12   Röcken bei Lützen, Prussian Provce of Saxony,...   630000        4
# 13               Florida, Missouri, The United States   673200        5
# 14                                  The United States   264950        2
# 15                                      Parral, Chile  1295000        4
# 16           Boston, Massachusetts, The United States   230000        4
# 17   Skopje, Macedonia, the Former Yugoslav Republ...   410000        4
# 18                  Anoka, Mnesota, The United States   247500        4
# 19         Greenville, Mississippi, The United States   325000        4
# 20                   Mneapolis, MN, The United States   134000        2
# 21                    Lewes, Sussex, The United Kgdom   315000        3
# 22                              Buenos Aires, Argenta   390000        3
# 23   South Farm, Arbury Hall, Nuneaton, Warwickshi...   260000        4
# 24             Bayonne, New Jersey, The United States   378000        4
# 25                                   Belfast, Ireland   351000        4
# 26                Atlanta, Georgia, The United States   291600        3
# 27                Harlem, New York, The United States   660000        3
# 28                                       Kyoto, Japan   292000        3
# 29                                      Paris, France   576750        3
# 30                     Connecticut, The United States   200000        4
# 31                Oak Park, Illois, The United States   368000        3
# 32              Tuscumbia, Alabama, The United States   396000        3
# 33                                      Dubl, Ireland   525000        4
# 34                                 Andernach, Germany   590000        4
# 35           Hartford, Connecticut, The United States   530000        3
# 36     Bloemfonte, Mangaung, Free State, South Africa   792500        3
# 37             Somersby, Lcolnshire, The United Kgdom   565000        3
# 38   Beaconsfield, Buckghamshire, England, The Uni...   547000        2
# 39             Manhattan, New York, The United States   291850        3
# 40              New York, New York, The United States   245000        3
# 41               Liverpool, England, The United Kgdom   515000        2
# 42             Darby, Pennsylvania, The United States   425000        4
# 43                 St. Petersburg, Russian Federation   825000        4
# 44               Seattle, Washgton, The United States   284200        3
# 45      Kirriemuir, Angus, Scotland, The United Kgdom   515000        3
# 46        Cambridge, Massachusetts, The United States   485000        4
# 47                                 Kabul, Afghanistan   527500        4
# 48            Monroeville, Alabama, The United States   340500        3
# 49         New York City, New York, The United States   296500        3
#
#    bathrooms sqft_living sqft_lot floors waterfront grade yr_built      lat  \
# 0       0.75        1240     4000      1          0     7     1968  40.7123
# 1        2.5        1060     1536      2          0     8     2000  38.8778
# 2        2.5        2540     5050      2          0     7     2006  33.9784
# 3          5        5310    16909      1          0    12     1992  42.8802
# 4       1.75        1530     9800      1          0     8     1958  37.6119
# 5          1         680     6400      1          0     6     1943  47.7890
# 6       1.75        1770     6000      1          0     7     1952  34.6356
# 7        3.5        2050     2020      2          0     8     2006  42.0902
# 8        1.5        1480     6752      1          0     7     1959  32.7916
# 9        3.5        2490     3582      2          0     8     2005  42.6669
# 10       2.5        2020     5613      2          0     7     2003  26.7401
# 11       2.5        2906     5893      2          0     9     2014  37.3409
# 12      2.75        2710    37277      2          0     9     2000  42.8802
# 13         3        4180     8561      2          0     7     2003  40.0528
# 14         1         770     7434      1          0     6     1947  45.5305
# 15       3.5        3790    90169      2          0    11     1998  37.9752
# 16       1.5        1050     9516      1          0     7     1969  35.5085
# 17         2        1580     9581      1          0     7     1953  37.4258
# 18      1.75        2290     7765      1          0     6     1936  44.5793
# 19         1        1400     9384    1.5          0     6     1948  32.3510
# 20       1.5         980     5000      2          0     7     1922  38.0329
# 21      1.75        1970     8200      1          0     7     1964  48.7664
# 22         1        1000     6947      1          0     7     1947  34.0528
# 23         2        1620     7992      2          0     7     1975  37.6529
# 24       2.5        1890    12236      1          0     7     1978  40.8348
# 25       2.5        2370     7274      2          0     7     1997  31.4700
# 26      1.75        1630     7480      1          0     7     1979  38.8980
# 27      1.75        1980     3300    1.5          0     7     1926  40.2753
# 28       2.5        1560     2740      2          0     8     1999  43.7253
# 29         2        2220     5000      1          0     7     1966  40.4316
# 30         2        1920     4822      1          0     6     1914  21.3055
# 31      1.75        2120    11340      1          0     7     1966  40.1171
# 32      1.75        2340     5668      1          0     6     1941  41.6780
# 33       2.5        3070     7200      2          0     8     2005  44.8604
# 34       1.5        2230     5109    1.5          0     7     1918  30.7139
# 35       2.5        1970     6295      2          0     7     2011  32.5109
# 36       1.5        1960     2400      2          0     8     1911  39.9560
# 37      1.75        1130     5111      1          0     7     1942  37.5303
# 38         1        1370    10038    1.5          0     7     1922  38.8624
# 39       1.5        1060     9711      1          0     7     1963  44.2632
# 40      1.75        1920     9306      1          0     7     1984  32.9123
# 41         1        1060     4960      1          0     7     1926  39.7759
# 42       2.5        2390     5021      2          0     7     2002  18.4008
# 43      2.75        3990     6637      2          0     9     2003  37.3554
# 44      1.75        1540     6632      1          0     7     1959  39.9894
# 45       2.5        3000     8250      1          0     8     1963  35.9007
# 46         2        1400     3600      1          0     7     1900  45.4517
# 47      2.25        2270     8480      1          0     8     1973  38.9148
# 48         2        2270    28025      1          0     7     1947  38.9532
# 49       1.5        1580    10100      1          0     7     1961  38.8680
#
#          long
# 0    -94.0385
# 1    -77.0672
# 2   -117.0405
# 3    -78.8432
# 4    -82.7187
# 5   -117.0142
# 6   -102.7123
# 7    -72.0532
# 8    -96.7526
# 9    -73.7866
# 10   -80.1104
# 11   -85.3317
# 12   -78.8432
# 13   -84.1107
# 14  -102.7918
# 15   -89.0421
# 16   -80.8206
# 17   -96.9173
# 18   -71.1740
# 19   -86.2743
# 20   -78.4703
# 21   -94.9439
# 22  -117.2339
# 23   -75.6611
# 24   -74.2650
# 25   -92.7651
# 26   -77.0233
# 27   -76.8711
# 28   -97.5880
# 29   -89.3043
# 30  -157.8447
# 31   -90.5572
# 32   -73.7979
# 33   -72.5842
# 34   -86.0386
# 35   -92.1363
# 36   -75.1506
# 37   -82.6206
# 38  -104.7565
# 39   -88.3846
# 40   -96.6182
# 41   -86.1383
# 42   -66.0534
# 43   -90.6879
# 44   -81.1697
# 45   -80.7921
# 46  -122.6901
# 47   -75.4267
# 48   -76.9472
# 49  -104.7562

# %% [markdown]
# ### Source 4: Zip Code API
# You may have observed that the *Source 3* data does not include the city and zip code information for
# the property locations for our 50 authors.  Your task is the use the latitude and longitude
# values from the *Source 3* data to locate the city and zip code information and incorporate
# that information into your dataframe.
#
# The USPS maintains data related to all US zip codes and their centroid latitude and longitude.  The
# *Source 3* data contains the latitude and longitude information (the lat and long tags) for the
# author locations. Your task
# is to use the *Source 3* latitude and longitude values as an argument to the zip code api in order to
# to augment your dataframe with the city name and zip code of the authors' locations.
#
# The ZIP code API contains ZIP codes for the
# continental United States, Alaska, Hawaii, Puerto Rico, and American Samoa.
# The API provides data in JSON format values for for ZIP code, city, latitude, longitude,
# timezone (offset from GMT).
#
# The relevant zip code API URL and parameters are shown in the table below.
#
#
# API Information and Parameters | Value
# ---------------------|------
# API Documentation | https://public.opendatasoft.com/explore/dataset/georef-united-states-of-america-zc-point/api/
# API URL | https://public.opendatasoft.com/api/records/1.0/search/
# dataset (parameter) | georef-united-states-of-america-zc-point
# rows (parameter) | 100
# geofilter.distance (parameter) | TBD by You. If used, distance value must by at least 10 kilometers
# Geofilter Documentation | https://help.opendatasoft.com/platform/en/exploring_catalog_and_datasets/03_searching_the_data/search.html#geo-filtering
# q (parameter) | TBD by You. If used, distance argument must by at least 10 kilometers. **Hint:** use the #distance function.
# Search Documentation | https://help.opendatasoft.com/platform/en/exploring_catalog_and_datasets/03_searching_the_data/search.html#full-text-search
# **Notes:** | use only one of either the *q* or *geofilter.distance* parameters. Do not use both.  The choice is yours.
#
# #### Tasks
# The long and lat values from *Source 3* are the exact longitude and latitude values for a
# single property location.  As such, it is unlikely that you will find an exact match from the
# zip code API using these values. Instead, you must:
#
# 1. round the lat and long values to 2 decimal place
# 2. invoke the API requesting all zip code related data within 10 kilometers from the
# rounded lat and long values. (Refer to the *q* or *geofilter.distance* parameter documentation listed above.)
# 3. If the returned JSON results indicate more that one candidate record has been returned, you
# must determine which record's longitude and latitude are the **closest** to the *Source 3*
# long and lat values.
# <br/><br/>There are several ways to accomplish this. For example, you could calculate the distance between the
# each result's longitude,latitude values and the the long, lat values from *Source 3*. The
# distance between the values can be calculated using the Pythagorean Theorem as follows: <br/>
# &radic;( (lon<sub>1</sub>-lon<sub>2</sub>)<sup>2</sup> + (lat<sub>1</sub>-lat<sub>2</sub>)<sup>2</sup> )
#  <br/><br/> Another, far better, approach involves a careful reading the documentation paying special attention to the *sort*
#  parameter. This is a hint...
# 4. Use the city and zip code that are associated with the result having the
#  minimum distance from (closest to) the *Source 3* long, lat values.

# %%
import json
import numpy as np

# %%
zipd = {}
cityList=[]
zipList=[]
def getzip(dic):
    #print("in getzip")
    min_ =min(dic.keys())
    #print(min_)
    for key,value in dic.items():
        if key == min_:
            #print(value)
            return value
            
    
        
def callonglat(lat1,long1,lat2,long2):
    #print("in callonglat")
    lat1,long1,lat2,long2 = np.round([float(lat1),float(long1),float(lat2),float(long2)],2)
    return np.sqrt(((long1)-long2)**2 + (lat1-lat2)**2)
    
def latlong(data_,a,o):
    #print("in latlong")
    zipd.clear()
    for len_ in range(len(data_['records'])):
        laT,lonG = data_['records'][len_]['geometry']['coordinates'][0],data_['records'][len_]['geometry']['coordinates'][1] 
        z = data_['records'][len_]['fields']['zip_code']
        ci = data_['records'][len_]['fields']['coty_name']
        #print(z,"\t\t",ci)
        zipd[callonglat(a,o,laT,lonG)] = [z,ci]
    #print(zipd)
    name1 = getzip(zipd)
    #print(name1)
    cityName,zipCode = name1[1],name1[0]
    return cityName,zipCode
    
def calculate():
    for i in range(len(source3)):
        #print(f"{i}th Run")
        latitude = round(float(source3['lat'].iloc[i]),2)
        longitude = round(float(source3['long'].iloc[i]),2)
        #print(latitude,longitude)
        dis =10*1000
        api = f'https://public.opendatasoft.com/api/records/1.0/search/?dataset=georef-united-states-of-america-zc-point&q=&facet=ste_name&facet=coty_name&facet=cty_code&geofilter.distance={latitude}%2C{longitude}%2C{dis}'
        r = requests.get(api).text
        var = json.loads(r)
        #print(var)
        city,zipco = latlong(var,latitude,longitude)
        cityList.append(city)
        zipList.append(zipco)
calculate()
source3['City'] = cityList
source3['Zip Code'] = zipList

# %%
source3
# Out:
#          key          Name of Author gender       Date of Birth  \
# 0   QWxiZXJ0         Albert Einstein      M      March 14, 1879
# 1   Si1LLVJv            J.K. Rowling      F       July 31, 1965
# 2   SmFuZS1B             Jane Austen      F   December 16, 1775
# 3   TWFyaWx5          Marilyn Monroe      F       June 01, 1926
# 4   QW5kcmUt              André Gide      M   November 22, 1869
# 5   VGhvbWFz        Thomas A. Edison      M   February 11, 1847
# 6   RWxlYW5v       Eleanor Roosevelt      F    October 11, 1884
# 7   U3RldmUt            Steve Martin      M     August 14, 1945
# 8   Qm9iLU1h              Bob Marley      M   February 06, 1945
# 9   RHItU2V1               Dr. Seuss      M      March 02, 1904
# 10  RG91Z2xh           Douglas Adams      M      March 11, 1952
# 11  RWxpZS1X             Elie Wiesel      M  September 30, 1928
# 12  RnJpZWRy     Friedrich Nietzsche      M    October 15, 1844
# 13  TWFyay1U              Mark Twain      M   November 30, 1835
# 14  QWxsZW4t          Allen Saunders      M      April 24, 1899
# 15  UGFibG8t            Pablo Neruda      M       July 12, 1904
# 16  UmFscGgt     Ralph Waldo Emerson      M        May 25, 1803
# 17  TW90aGVy           Mother Teresa      F     August 26, 1910
# 18  R2Fycmlz        Garrison Keillor      M     August 07, 1942
# 19  SmltLUhl              Jim Henson      M  September 24, 1936
# 20  Q3hhcmxl       Charles M. Schulz      M   November 26, 1922
# 21  V2lsbGlh       William Nicholson      M    January 12, 1948
# 22  Sm9yZ2Ut       Jorge Luis Borges      M     August 24, 1899
# 23  R4Vvcmdl            George Eliot      F   November 22, 1819
# 24  R5Vvcmdl      George R.R. Martin      M  September 20, 1948
# 25  Qy1TLUxl              C.S. Lewis      M   November 29, 1898
# 26  TWFydGlu  Martin Luther King Jr.      M    January 15, 1929
# 27  SmFtZXMt           James Baldwin      M     August 02, 1924
# 28  SGFydWtp         Haruki Murakami      M    January 12, 1949
# 29  QWxleGFu    Alexandre Dumas fils      M       July 27, 1824
# 30  U3RlcGhl         Stephenie Meyer      F   December 24, 1973
# 31  RXJuZXN0        Ernest Hemingway      M       July 21, 1899
# 32  SGVsZW4t            Helen Keller      F       June 27, 1880
# 33  R2Vvcmdl     George Bernard Shaw      M       July 26, 1856
# 34  Q2hhcmxl        Charles Bukowski      M     August 16, 1920
# 35  U3V6YW5u         Suzanne Collins      F     August 11, 1962
# 36  Si1SLVIt          J.R.R. Tolkien      M    January 03, 1892
# 37  QWxmcmVk         Alfred Tennyson      M     August 06, 1809
# 38  VGVycnkt         Terry Pratchett      M      April 28, 1948
# 39  Si1ELVNh           J.D. Salinger      M    January 01, 1919
# 40  R3Vvcmdl           George Carlin      M        May 12, 1937
# 41  Sm9obi1M             John Lennon      M    October 09, 1940
# 42  Vy1DLUZp             W.C. Fields      M    January 29, 1880
# 43  QXluLVJh                Ayn Rand      F   February 02, 1905
# 44  SmltaS1I            Jimi Hendrix      M   November 27, 1942
# 45  Si1NLUJh             J.M. Barrie      M        May 09, 1860
# 46  RS1FLUN1           E.E. Cummings      M    October 14, 1894
# 47  S2hhbGVk         Khaled Hosseini      M      March 04, 1965
# 48  SGFycGVy              Harper Lee      F      April 28, 1926
# 49  TWFkZWxl       Madeleine L'Engle      F   November 29, 1918
#
#                                        Place of Birth    price bedrooms  \
# 0                                        Ulm, Germany   699999        3
# 1    Yate, South Gloucestershire, England, The Uni...   415000        3
# 2      Steventon Rectory, Hampshire, The United Kgdom   300000        3
# 3                                   The United States  2480000        4
# 4                                       Paris, France   425000        3
# 5                      Milan, Ohio, The United States   179900        2
# 6                                   The United States   420000        3
# 7                      Waco, Texas, The United States   761000        3
# 8                           Ne Mile, Sat Ann, Jamaica   307150        3
# 9                    Sprgfield, MA, The United States   550000        3
# 10               Cambridge, England, The United Kgdom   528000        3
# 11                                    Sighet, Romania   418395        4
# 12   Röcken bei Lützen, Prussian Provce of Saxony,...   630000        4
# 13               Florida, Missouri, The United States   673200        5
# 14                                  The United States   264950        2
# 15                                      Parral, Chile  1295000        4
# 16           Boston, Massachusetts, The United States   230000        4
# 17   Skopje, Macedonia, the Former Yugoslav Republ...   410000        4
# 18                  Anoka, Mnesota, The United States   247500        4
# 19         Greenville, Mississippi, The United States   325000        4
# 20                   Mneapolis, MN, The United States   134000        2
# 21                    Lewes, Sussex, The United Kgdom   315000        3
# 22                              Buenos Aires, Argenta   390000        3
# 23   South Farm, Arbury Hall, Nuneaton, Warwickshi...   260000        4
# 24             Bayonne, New Jersey, The United States   378000        4
# 25                                   Belfast, Ireland   351000        4
# 26                Atlanta, Georgia, The United States   291600        3
# 27                Harlem, New York, The United States   660000        3
# 28                                       Kyoto, Japan   292000        3
# 29                                      Paris, France   576750        3
# 30                     Connecticut, The United States   200000        4
# 31                Oak Park, Illois, The United States   368000        3
# 32              Tuscumbia, Alabama, The United States   396000        3
# 33                                      Dubl, Ireland   525000        4
# 34                                 Andernach, Germany   590000        4
# 35           Hartford, Connecticut, The United States   530000        3
# 36     Bloemfonte, Mangaung, Free State, South Africa   792500        3
# 37             Somersby, Lcolnshire, The United Kgdom   565000        3
# 38   Beaconsfield, Buckghamshire, England, The Uni...   547000        2
# 39             Manhattan, New York, The United States   291850        3
# 40              New York, New York, The United States   245000        3
# 41               Liverpool, England, The United Kgdom   515000        2
# 42             Darby, Pennsylvania, The United States   425000        4
# 43                 St. Petersburg, Russian Federation   825000        4
# 44               Seattle, Washgton, The United States   284200        3
# 45      Kirriemuir, Angus, Scotland, The United Kgdom   515000        3
# 46        Cambridge, Massachusetts, The United States   485000        4
# 47                                 Kabul, Afghanistan   527500        4
# 48            Monroeville, Alabama, The United States   340500        3
# 49         New York City, New York, The United States   296500        3
#
#    bathrooms sqft_living sqft_lot floors waterfront grade yr_built      lat  \
# 0       0.75        1240     4000      1          0     7     1968  40.7123
# 1        2.5        1060     1536      2          0     8     2000  38.8778
# 2        2.5        2540     5050      2          0     7     2006  33.9784
# 3          5        5310    16909      1          0    12     1992  42.8802
# 4       1.75        1530     9800      1          0     8     1958  37.6119
# 5          1         680     6400      1          0     6     1943  47.7890
# 6       1.75        1770     6000      1          0     7     1952  34.6356
# 7        3.5        2050     2020      2          0     8     2006  42.0902
# 8        1.5        1480     6752      1          0     7     1959  32.7916
# 9        3.5        2490     3582      2          0     8     2005  42.6669
# 10       2.5        2020     5613      2          0     7     2003  26.7401
# 11       2.5        2906     5893      2          0     9     2014  37.3409
# 12      2.75        2710    37277      2          0     9     2000  42.8802
# 13         3        4180     8561      2          0     7     2003  40.0528
# 14         1         770     7434      1          0     6     1947  45.5305
# 15       3.5        3790    90169      2          0    11     1998  37.9752
# 16       1.5        1050     9516      1          0     7     1969  35.5085
# 17         2        1580     9581      1          0     7     1953  37.4258
# 18      1.75        2290     7765      1          0     6     1936  44.5793
# 19         1        1400     9384    1.5          0     6     1948  32.3510
# 20       1.5         980     5000      2          0     7     1922  38.0329
# 21      1.75        1970     8200      1          0     7     1964  48.7664
# 22         1        1000     6947      1          0     7     1947  34.0528
# 23         2        1620     7992      2          0     7     1975  37.6529
# 24       2.5        1890    12236      1          0     7     1978  40.8348
# 25       2.5        2370     7274      2          0     7     1997  31.4700
# 26      1.75        1630     7480      1          0     7     1979  38.8980
# 27      1.75        1980     3300    1.5          0     7     1926  40.2753
# 28       2.5        1560     2740      2          0     8     1999  43.7253
# 29         2        2220     5000      1          0     7     1966  40.4316
# 30         2        1920     4822      1          0     6     1914  21.3055
# 31      1.75        2120    11340      1          0     7     1966  40.1171
# 32      1.75        2340     5668      1          0     6     1941  41.6780
# 33       2.5        3070     7200      2          0     8     2005  44.8604
# 34       1.5        2230     5109    1.5          0     7     1918  30.7139
# 35       2.5        1970     6295      2          0     7     2011  32.5109
# 36       1.5        1960     2400      2          0     8     1911  39.9560
# 37      1.75        1130     5111      1          0     7     1942  37.5303
# 38         1        1370    10038    1.5          0     7     1922  38.8624
# 39       1.5        1060     9711      1          0     7     1963  44.2632
# 40      1.75        1920     9306      1          0     7     1984  32.9123
# 41         1        1060     4960      1          0     7     1926  39.7759
# 42       2.5        2390     5021      2          0     7     2002  18.4008
# 43      2.75        3990     6637      2          0     9     2003  37.3554
# 44      1.75        1540     6632      1          0     7     1959  39.9894
# 45       2.5        3000     8250      1          0     8     1963  35.9007
# 46         2        1400     3600      1          0     7     1900  45.4517
# 47      2.25        2270     8480      1          0     8     1973  38.9148
# 48         2        2270    28025      1          0     7     1947  38.9532
# 49       1.5        1580    10100      1          0     7     1961  38.8680
#
#          long                          City Zip Code
# 0    -94.0385              Decatur|Ringgold    50140
# 1    -77.0672          District of Columbia    20245
# 2   -117.0405                     Riverside    92223
# 3    -78.8432                          Erie    14220
# 4    -82.7187                         Floyd    41659
# 5   -117.0142                      Kootenai    83854
# 6   -102.7123             Parmer|Deaf Smith    79035
# 7    -72.0532                     Worcester     1550
# 8    -96.7526                        Dallas    75215
# 9    -73.7866                        Albany    12202
# 10   -80.1104                    Palm Beach    33480
# 11   -85.3317     Taylor|Marion|Green|Larue    42718
# 12   -78.8432                          Erie    14220
# 13   -84.1107                     Champaign    45389
# 14  -102.7918               Perkins|Harding    57649
# 15   -89.0421                      Franklin    62874
# 16   -80.8206  Mecklenburg|Cabarrus|Iredell    28036
# 17   -96.9173                        Cowley    67131
# 18   -71.1740                          Coos     3570
# 19   -86.2743                    Montgomery    36111
# 20   -78.4703     Charlottesville|Albemarle    22902
# 21   -94.9439             Lake of the Woods    56686
# 22  -117.2339      San Bernardino|Riverside    92373
# 23   -75.6611                      Accomack    23480
# 24   -74.2650                         Essex     7028
# 25   -92.7651   Rapides|Natchitoches|Vernon    71447
# 26   -77.0233          District of Columbia    20510
# 27   -76.8711                       Dauphin    17113
# 28   -97.5880                 McCook|Hanson    57374
# 29   -89.3043                        McLean    61774
# 30  -157.8447                      Honolulu    96816
# 31   -90.5572                      Schuyler    62681
# 32   -73.7979                      Dutchess    12540
# 33   -72.5842                       Orleans     5874
# 34   -86.0386                        Walton    32435
# 35   -92.1363                      Ouachita    71209
# 36   -75.1506                        Camden     8102
# 37   -82.6206                          Pike    41501
# 38  -104.7565                       El Paso    80916
# 39   -88.3846             Winnebago|Calumet    54952
# 40   -96.6182                        Dallas    75043
# 41   -86.1383                        Marion    46219
# 42   -66.0534             San Juan|Carolina      924
# 43   -90.6879                          Iron    63675
# 44   -81.1697                       Belmont    43719
# 45   -80.7921                 Iredell|Davie    28634
# 46  -122.6901                     Clackamas    97267
# 47   -75.4267                        Sussex    19960
# 48   -76.9472               Prince George's    20710
# 49  -104.7562                       El Paso    80914

# %% [markdown]
# ## Proof of Concept
# Use the dataframe that you constructed above to answer the following three questions.
#
# ### Question 1
# What is the mean and standard deviation of living space (sqft_living) by number of bedrooms? Use the pandas
# dataframe.agg() method to calculate these statistics in a single step.
#
# ### Question 2
# How many authors, by gender, live on lots that exceed the mean lot size (sqft_lot) by more
# than 1 standard deviation.
#
# ### Question 3
# Examine the documentation for the pandas dataframe.cut() method
# [Docs](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html)
#
# Use this method to convert the *price* attribute into to
# 3 approximately equal sized bins. Assign each bin specific labels of 'low', 'medium', 'high'.
# How many authors are there in each price category?

# %% [markdown]
# #### Question 1 What is the mean and standard deviation of living space (sqft_living) by number of bedrooms? Use the pandas dataframe.agg() method to calculate these statistics in a single step.

# %%
source3['sqft_living'] = source3['sqft_living'].apply(lambda x : int(x))
source3['bedrooms'] = source3['bedrooms'].apply(lambda x: int(x))
s3 = source3.groupby(['bedrooms'])
s3.agg({'sqft_living':['mean','std']})
# Out:
#           sqft_living
#                  mean          std
# bedrooms
# 2          972.000000   270.314631
# 3         1824.230769   504.271142
# 4         2454.777778  1066.275130
# 5         4180.000000          NaN

# %% [markdown]
# ## Question 2
# ### How many authors, by gender, live on lots that exceed the mean lot size (sqft_lot) by more than 1 standard deviation.

# %%
source3['sqft_lot'] = source3['sqft_lot'].apply(lambda x:int(x))
s2 = source3.groupby('gender')
meanLotSize = s2.agg({'sqft_lot':['mean','std']})
print("Mean and Standard Deviation of Lot Size\n",meanLotSize)
female_mean = meanLotSize['sqft_lot']['mean'][0]
male_mean = meanLotSize['sqft_lot']['mean'][1]
female_std = meanLotSize['sqft_lot']['std'][0]
male_std = meanLotSize['sqft_lot']['std'][1]
male_data = []
female_data =[]
for i in range(len(source3)):
    if source3['gender'].iloc[i] == 'M':
        male_data.append(source3['sqft_lot'].iloc[i])
    else:
        female_data.append(source3['sqft_lot'].iloc[i])

def calZ(data_,mean,std):
    count = 0
    for i in data_:
        z = (i-mean)/std
        if z > 1:
            count+=1
    return count
    
    
no_of_male = calZ(male_data,male_mean,male_std)
no_of_female = calZ(female_data,female_mean,female_std)
print(f"\n\n{no_of_male} male authors and {no_of_female} Female authors, live on lots that exceed the mean lot size (sqft_lot) by more than 1 standard deviation")
# Out:
# Mean and Standard Deviation of Lot Size
#             sqft_lot
#                mean           std
# gender
# F       9051.250000   7063.398038
# M       9723.710526  14505.911876
#
#
# 2 male authors and 2 Female authors, live on lots that exceed the mean lot size (sqft_lot) by more than 1 standard deviation

# %% [markdown]
# ### Question 3
# Examine the documentation for the pandas dataframe.cut() method
# [Docs](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html)
#
# Use this method to convert the *price* attribute into to
# 3 approximately equal sized bins. Assign each bin specific labels of 'low', 'medium', 'high'.
# How many authors are there in each price category?

# %%
source3['price'] = source3['price'].apply(lambda x: int(x)) 
price_category = pd.cut(source3['price'], bins=3, right=False,labels =['Low','Medium','High'])
low = 0
medium =0
high = 0
for i in price_category:
    if i =='Low':
        low+=1
    elif i == 'Medium':
        medium+=1
    else:
        high+=1
print(f"\nAuthors in Price Categories\n\nLow\tMedium\tHigh\n{low}\t{medium}\t{high}")
# Out:
# Authors in Price Categories
#
# Low	Medium	High
# 48	1	1

# %% [markdown]
# ## Deliverable
# Due to the the implementation of the JNB app, it is very easy to create circular variable dependencies. Such
# dependencies will thwart my ability to run your entire JNB solution and result in the loss of valuable project points.
#
# To ensure that your have not inadvertently created such dependencies, I **strongly** recommend you perform the following steps
# prior to submitting your JNB.
#
# 1. Clear all outputs from your JNB solution's code cells
# 1. Save you JNB solution
# 1. Stop and restart your JNB kernel via the *Kernel* Jupyter Notebook menu item. Use the
# *Restart & Run All Output* menu item.
# 1. Inspect your output cells for any errors
#
# Once you have completed your project, upload the JNB containing your solution to the
# *Course Project* assessment item located in the *Course Project* content area on our Blackboard site.
